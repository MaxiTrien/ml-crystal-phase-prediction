# %%
import pandas as pd
import numpy as np
import pathlib
from matminer.featurizers.structure import XRDPowderPattern

# %%
# Select from the following choose of data
#
# structure_df_all.pkl # hfo2 and zro2 
# structure_df_hfo2.pkl
# structure_df_zro2.pkl
# more...
#

# %%
# pathfile = r'C:\Python\Projects\crystal-phase-prediction\data\pkl_files\structures\structure_df_zro2.pkl' #  structure for hfo2
# pathfile = r'C:\Python\Projects\crystal-phase-prediction\data\pkl_files\structures\structure_df_hfo2.pkl' #  structure for hfo2
# pathfile = r'C:\Python\Projects\crystal-phase-prediction\data\pkl_files\structures\structure_df_hfo2_deg.pkl' # degrees changed
pathfile = r'C:\Python\Projects\crystal-phase-prediction\data\pkl_files\structures\structure_df_hfo2_La_del.pkl'

path = pathlib.WindowsPath(pathfile)
df = pd.read_pickle(path)
df
# Out:
#                                              structure  \
# 0    [[1.2928479  5.17927294 1.26819645] Hf, [1.293...
# 1    [[-3.77885157e+00  2.73707898e-03 -3.81414680e...
# 2    [[-3.79660671 -5.1630596   1.27059801] Hf, [-3...
# 3    [[ 0.99913941 -9.9788178  -8.49936051] La, [ 1...
# 4    [[-3.83886481 -0.03604068 -9.12670293] La, [-1...
# ..                                                 ...
# 334  [[ 1.26849616 -2.59236768  1.26845884] La, [ 1...
# 335  [[-5.17180394  2.61804914 -3.56442079] La, [-8...
# 336  [[5.99738519 2.70065929 0.2573197 ] La, [1.407...
# 337  [[-8.7955774  -7.50515665 -0.30954248] La, [-9...
# 338  [[-8.74761452 -7.85175277  1.05666296] La, [-8...
#
#                                name
# 0      Hf14La2O32_sc122_No137_1.cif
# 1      Hf14La2O32_sc122_No137_2.cif
# 2      Hf14La2O32_sc122_No137_3.cif
# 3      Hf14La2O32_sc122_No137_4.cif
# 4      Hf14La2O32_sc122_No137_5.cif
# ..                              ...
# 334    La_HfO2_inter_6.25_212_t.cif
# 335    La_HfO2_inter_6.25_221_m.cif
# 336    La_HfO2_inter_6.25_221_o.cif
# 337  La_HfO2_inter_6.25_221_p-o.cif
# 338    La_HfO2_inter_6.25_221_t.cif
#
# [339 rows x 2 columns]

# %%
xrd = XRDPowderPattern(two_theta_range=(5, 65))
df = xrd.fit_featurize_dataframe(df, 'structure')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='XRDPowderPattern', max=339.0, style=ProgressStyle(descrip…

# %%
df = df.drop(columns = 'labels')
df
# Out:
#                                             structure  \
# 0   [[ 1.36459548  5.41503098 -3.86106899] Hf, [ 1...
# 1   [[1.341085   0.18425587 6.37172445] Hf, [1.310...
# 2   [[1.33465783 0.16493041 6.34529803] Hf, [1.396...
# 3   [[ 1.24453579  0.01069707 -9.04812028] La, [ 1...
# 4   [[ -3.75097439 -10.43915897  -9.12936741] La, ...
# ..                                                ...
# 94  [[-8.91737071 -7.87002883 -6.31688805] La, [-6...
# 95  [[-6.32739935 -7.76218739 -8.93890052] La, [-6...
# 96  [[  5.49959237  -7.55914851 -10.43734567] La, ...
# 97  [[-4.39644506  2.97034064  0.3334635 ] La, [-8...
# 98  [[5.99738519 2.70065929 0.2573197 ] La, [1.407...
#
#                              name         xrd_0         xrd_1         xrd_2  \
# 0     Hf14La2O32_sc122_No29_1.cif  1.600793e-09  2.282765e-06  2.690808e-04
# 1     Hf14La2O32_sc122_No29_2.cif  1.760559e-10  4.817747e-07  1.067549e-04
# 2     Hf14La2O32_sc122_No29_3.cif  1.157423e-30  1.723137e-23  2.069997e-17
# 3     Hf14La2O32_sc122_No29_4.cif  9.241153e-10  1.410563e-06  1.878075e-04
