# 2    ...  0.034138  0.020162  0.019145  0.014343  0.015809  0.012623
# 3    ...  0.032058  0.021512  0.020327  0.014785  0.019164  0.017702
# 4    ...  0.034602  0.021167  0.019106  0.014056  0.020409  0.014490
# ..   ...       ...       ...       ...       ...       ...       ...
# 104  ...  0.031493  0.026097  0.018888  0.014445  0.014715  0.017909
# 105  ...  0.048573  0.024808  0.019571  0.011731  0.014365  0.018520
# 106  ...  0.045022  0.025119  0.016385  0.009977  0.017488  0.019553
# 107  ...  0.040686  0.023225  0.018862  0.009975  0.019371  0.019917
# 108  ...  0.046184  0.025972  0.012554  0.013392  0.012580  0.012787
#
#        xrd_57    xrd_58    xrd_59    xrd_60
# 0    0.018991  0.027547  0.010975  0.002812
# 1    0.020183  0.025696  0.012174  0.003422
# 2    0.020545  0.026228  0.009766  0.003336
# 3    0.020996  0.025160  0.006552  0.002268
# 4    0.023569  0.025117  0.006487  0.002040
# ..        ...       ...       ...       ...
# 104  0.015298  0.028236  0.015600  0.001112
# 105  0.018931  0.010708  0.013570  0.014202
# 106  0.011065  0.006172  0.013643  0.012913
# 107  0.011551  0.004816  0.012755  0.013280
# 108  0.015576  0.014012  0.010529  0.011219
#
# [109 rows x 63 columns]

# %%
labels = pd.read_pickle(r'C:\Python\Projects\crystal-phase-prediction\data\data_labels\La_defects_labels_m.pkl')
labels
# Out:
# 0        2La
# 1        2La
# 2        2La
# 3        2La
# 4        2La
#        ...
# 104     La2V
# 105    inter
# 106    inter
# 107    inter
# 108    inter
# Name: labels, Length: 109, dtype: object

# %%
df_joined = pd.concat([df, labels], axis=1)
df_joined
# Out:
#                                              structure  \
# 0    [[ 1.43364347 -5.05458306  1.7612222 ] Hf, [ 1...
# 1    [[-3.63321709  0.12925241 -9.6815268 ] La, [-1...
# 2    [[-3.73360452  0.13446417 -9.63545356] La, [-1...
# 3    [[-3.64748426  0.22497602 -4.26243513] Hf, [-3...
# 4    [[1.41818387 0.19806804 7.03567622] Hf, [1.419...
# ..                                                 ...
# 104  [[3.60419766 2.64602632 1.82503961] La, [ 3.66...
# 105  [[-5.19078639  2.52186112 -8.74118441] La, [ -...
# 106  [[-0.07300294  2.58948902 -8.00033005] La, [-3...
# 107  [[ 4.99292181 -2.5924109   3.70489325] La, [ 1...
# 108  [[-5.17180394  2.61804914 -3.56442079] La, [-8...
#
#                               name         xrd_0         xrd_1         xrd_2  \
# 0      Hf14La2O32_sc122_No14_1.cif  1.223605e-09  1.915600e-06  2.443198e-04
# 1     Hf14La2O32_sc122_No14_10.cif  1.650955e-09  2.473637e-06  3.147547e-04
# 2     Hf14La2O32_sc122_No14_11.cif  9.629694e-10  1.657197e-06  2.283409e-04
# 3      Hf14La2O32_sc122_No14_2.cif  4.558260e-10  9.404558e-07  1.515354e-04
# 4      Hf14La2O32_sc122_No14_3.cif  7.953870e-31  1.408130e-23  1.927222e-17
# ..                             ...           ...           ...           ...
# 104    Hf30La2O63_sc222_No14_9.cif  2.721865e-93  1.628106e-79  7.105898e-67
# 105  La_HfO2_inter_3.125_222_m.cif  9.098612e-96  8.264667e-82  5.494839e-69
# 106   La_HfO2_inter_6.25_122_m.cif  9.520707e-11  2.913841e-07  6.065465e-05
# 107   La_HfO2_inter_6.25_212_m.cif  9.613701e-11  2.479832e-07  4.592929e-05
# 108   La_HfO2_inter_6.25_221_m.cif  4.585557e-98  1.306352e-83  2.412312e-70
#
#             xrd_3         xrd_4         xrd_5         xrd_6         xrd_7  \
# 0    2.538649e-03  2.149001e-03  1.482043e-04  8.326745e-07  3.811358e-10
# 1    3.401832e-03  3.123294e-03  2.478184e-04  1.792516e-04  6.350770e-04
# 2    2.520545e-03  2.230351e-03  1.583047e-04  9.018381e-07  4.126070e-10
# 3    1.906893e-03  1.874024e-03  1.438336e-04  8.621479e-07  4.035894e-10
# 4    2.039100e-12  1.667834e-08  1.054538e-05  5.154092e-04  1.947176e-03
# ..            ...           ...           ...           ...           ...
# 104  2.262951e-55  5.258370e-45  8.915528e-36  1.102968e-27  9.956318e-21
# 105  2.674016e-57  9.524726e-47  2.483250e-37  4.738792e-29  6.619030e-22
# 106  8.597639e-04  8.303964e-04  5.464863e-05  2.448947e-07  7.463887e-11
# 107  6.802241e-04  9.484300e-04  1.286273e-04  1.729751e-06  4.366817e-05
# 108  2.887436e-58  2.240250e-47  1.126642e-37  3.672660e-29  7.760342e-22
#
#      ...    xrd_52    xrd_53    xrd_54    xrd_55    xrd_56    xrd_57  \
# 0    ...  0.021853  0.022759  0.016539  0.014751  0.013524  0.018991
# 1    ...  0.018231  0.020503  0.014204  0.016118  0.014339  0.020183
# 2    ...  0.020162  0.019145  0.014343  0.015809  0.012623  0.020545
# 3    ...  0.021512  0.020327  0.014785  0.019164  0.017702  0.020996
# 4    ...  0.021167  0.019106  0.014056  0.020409  0.014490  0.023569
# ..   ...       ...       ...       ...       ...       ...       ...
# 104  ...  0.026097  0.018888  0.014445  0.014715  0.017909  0.015298
# 105  ...  0.024808  0.019571  0.011731  0.014365  0.018520  0.018931
# 106  ...  0.025119  0.016385  0.009977  0.017488  0.019553  0.011065
# 107  ...  0.023225  0.018862  0.009975  0.019371  0.019917  0.011551
# 108  ...  0.025972  0.012554  0.013392  0.012580  0.012787  0.015576
#
#        xrd_58    xrd_59    xrd_60  labels
# 0    0.027547  0.010975  0.002812     2La
# 1    0.025696  0.012174  0.003422     2La
# 2    0.026228  0.009766  0.003336     2La
# 3    0.025160  0.006552  0.002268     2La
# 4    0.025117  0.006487  0.002040     2La
# ..        ...       ...       ...     ...
# 104  0.028236  0.015600  0.001112    La2V
# 105  0.010708  0.013570  0.014202   inter
# 106  0.006172  0.013643  0.012913   inter
# 107  0.004816  0.012755  0.013280   inter
# 108  0.014012  0.010529  0.011219   inter
#
# [109 rows x 64 columns]

# %%
df_2La = df_joined[df_joined['labels'].str.contains('2La',case=False)]
df_La2V =  df_joined[df_joined['labels'].str.contains('La2V',case=False)]
df_inter =  df_joined[df_joined['labels'].str.contains('inter',case=False)]
df_LaV =  df_joined[df_joined['labels'].str.contains('LaV',case=False)]

X_2La = df_2La.iloc[:, 2:-1].values
X_La2V = df_La2V.iloc[:, 2:-1].values
X_inter =  df_inter.iloc[:, 2:-1].values
X_LaV = df_LaV.iloc[:, 2:-1].values

# %%
theta2 = np.array(range(5, 66))

# %%
fig=plt.figure(figsize=(13, 7))
rang = [X_2La.shape[0], X_La2V.shape[0], X_inter.shape[0], X_LaV.shape[0]]
df_arr = [X_2La, X_La2V, X_inter, X_LaV]
for ran, X in zip(rang, df_arr):
    for i in range(ran):
        plt.plot(theta2, X[i, :], alpha= 0.4)
    
plt.xlim([theta2.min(), theta2.max()])
plt.xlabel('$2theta)$')
plt.ylabel('Diffracted intensity (A.u.)')
plt.title('Crystal diffraction HfO2 defects')
# Out:
# Text(0.5, 1.0, 'Crystal diffraction HfO2 defects')

# %%
fig=plt.figure(figsize=(13, 7))
ran =  X_2La.shape[0]

for i in range(ran):
    plt.plot(theta2, X_2La[i, :], alpha= 0.4)

plt.xlim([theta2.min(), theta2.max()])
plt.xlabel('$2theta)$')
plt.ylabel('Diffracted intensity (A.u.)')
plt.title('2La XRD defect')
# Out:
# Text(0.5, 1.0, '2La XRD defect')

# %%
fig=plt.figure(figsize=(13, 7))
ran =  X_La2V.shape[0]

for i in range(ran):
    plt.plot(theta2, X_La2V[i, :], alpha= 0.4)

plt.xlim([theta2.min(), theta2.max()])
plt.xlabel('$2theta)$')
plt.ylabel('Diffracted intensity (A.u.)')
plt.title('La2V XRD defects')
# Out:
# Text(0.5, 1.0, 'La2V XRD defects')

# %%
fig=plt.figure(figsize=(13, 7))
ran =  X_inter.shape[0]

for i in range(ran):
    plt.plot(theta2, X_inter[i, :], alpha= 0.4)

plt.xlim([theta2.min(), theta2.max()])
plt.xlabel('$2theta)$')
plt.ylabel('Diffracted intensity (A.u.)')
plt.title('inter XRD defects')
# Out:
# Text(0.5, 1.0, 'inter XRD defects')

# %%
fig=plt.figure(figsize=(13, 7))
ran =  X_LaV.shape[0]

for i in range(ran):
    plt.plot(theta2, X_LaV[i, :], alpha= 0.4)

plt.xlim([theta2.min(), theta2.max()])
plt.xlabel('$2theta)$')
plt.ylabel('Diffracted intensity (A.u.)')
plt.title('LaV XRD defect')
# Out:
# Text(0.5, 1.0, 'LaV XRD defect')

# %%
f = plt.figure(figsize=(18,9))

ax1 = f.add_subplot(221)


ran =  X_2La.shape[0]
for i in range(ran):
    ax1.plot(theta2, X_2La[i, :], alpha= 0.4)

ax2 = f.add_subplot(222)
ran =  X_La2V.shape[0]
for i in range(ran):
    ax2.plot(theta2, X_La2V[i, :], alpha= 0.4)
    
ax3 = f.add_subplot(223)
ran =  X_inter.shape[0]
for i in range(ran):
    ax3.plot(theta2, X_inter[i, :], alpha= 0.4)
    
ax4 = f.add_subplot(224)
ran =  X_LaV.shape[0]
for i in range(ran):
    ax4.plot(theta2, X_LaV[i, :], alpha= 0.4)
    
f.tight_layout(pad=5.0)
ax1.set_xlabel('2theta')
ax2.set_xlabel('2theta')
ax3.set_xlabel('2theta')
ax4.set_xlabel('2theta')
ax1.set_ylabel('Diffracted intensity (A.u.)')
ax2.set_ylabel('Diffracted intensity (A.u.)')
ax3.set_ylabel('Diffracted intensity (A.u.)')
ax4.set_ylabel('Diffracted intensity (A.u.)')
ax1.set_title('2La XRD defect')
ax2.set_title('La2V XRD defects')
ax3.set_title('inter XRD defects')
ax4.set_title('LaV XRD defect')
f.suptitle("Defects in XRD monoclinic phase", fontsize=18)
plt.show()
