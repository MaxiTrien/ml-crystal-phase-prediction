# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
df = pd.read_pickle(r'C:\Python\Projects\crystal-phase-prediction\data\pkl_files\structures\structure_df_hfo2_La_del.pkl')

# %%
# for phase detection 
#df.name = df.name.str.replace('No14','m')
#df.name = df.name.str.replace('No137','t')
#df.name = df.name.str.replace('No29','o')
#df.name= df.name.str.replace('No61','p-o')
#df

# %%
# for defects detection 
df_Hf14La2O32 = df[df['name'].str.contains('Hf14La2O32',case=False)]
df_Hf30La2O64 =  df[df['name'].str.contains('Hf30La2O64',case=False)]
df_Hf15LaO31 =  df[df['name'].str.contains('Hf15LaO31',case=False)]
df_Hf31LaO63 =  df[df['name'].str.contains('Hf31LaO63',case=False)]
df_Hf30La2O63 =  df[df['name'].str.contains('Hf30La2O63',case=False)]
df_La_HfO2_cat =  df[df['name'].str.contains('La_HfO2_cat',case=False)]
df_La_HfO2_inter =  df[df['name'].str.contains('La_HfO2_inter',case=False)]


df_Hf14La2O32['labels'] = df_Hf14La2O32['name'].str.extract(r'(Hf14La2O32)') # zwei La
df_Hf30La2O64['labels'] = df_Hf30La2O64['name'].str.extract(r'(Hf30La2O64)') 
df_La_HfO2_cat['labels'] = df_La_HfO2_cat['name'].str.extract(r'(cat)') # zwei La

df_Hf15LaO31['labels'] = df_Hf15LaO31['name'].str.extract(r'(Hf15LaO31)') # LaV
df_Hf31LaO63['labels'] = df_Hf31LaO63['name'].str.extract(r'(Hf31LaO63)')

df_Hf30La2O63['labels'] = df_Hf30La2O63['name'].str.extract(r'(Hf30La2O63)') # La2V

df_La_HfO2_inter['labels'] = df_La_HfO2_inter['name'].str.extract(r'(inter)') # inter


df = pd.concat([df_Hf14La2O32, df_Hf30La2O64, df_La_HfO2_cat, df_Hf15LaO31, df_Hf31LaO63, df_Hf30La2O63, df_La_HfO2_inter], axis=0)
df.shape
# Out:
# <ipython-input-61-54e091d55025>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Hf14La2O32['labels'] = df_Hf14La2O32['name'].str.extract(r'(Hf14La2O32)') # zwei La
# <ipython-input-61-54e091d55025>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Hf30La2O64['labels'] = df_Hf30La2O64['name'].str.extract(r'(Hf30La2O64)')
# <ipython-input-61-54e091d55025>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_La_HfO2_cat['labels'] = df_La_HfO2_cat['name'].str.extract(r'(cat)') # zwei La
# <ipython-input-61-54e091d55025>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Hf15LaO31['labels'] = df_Hf15LaO31['name'].str.extract(r'(Hf15LaO31)') # LaV
# <ipython-input-61-54e091d55025>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Hf31LaO63['labels'] = df_Hf31LaO63['name'].str.extract(r'(Hf31LaO63)')
# <ipython-input-61-54e091d55025>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Hf30La2O63['labels'] = df_Hf30La2O63['name'].str.extract(r'(Hf30La2O63)') # La2V
# <ipython-input-61-54e091d55025>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_La_HfO2_inter['labels'] = df_La_HfO2_inter['name'].str.extract(r'(inter)') # inter
# (99, 3)

# %%
df['labels'].replace({'Hf14La2O32': '2La', 'Hf30La2O64': '2La', 'cat': '2La', 'Hf15LaO31': 'LaV', 'Hf31LaO63':'LaV',
                     'Hf30La2O63': 'La2V'},
                          inplace=True)
df.shape
# Out:
# (99, 3)

# %%
df.labels.value_counts()
# Out:
# 2La      52
# LaV      32
# La2V     12
# inter     3
# Name: labels, dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                             structure  \
# 0   [[ 1.36459548  5.41503098 -3.86106899] Hf, [ 1...
# 1   [[1.341085   0.18425587 6.37172445] Hf, [1.310...
# 2   [[1.33465783 0.16493041 6.34529803] Hf, [1.396...
# 3   [[ 1.24453579  0.01069707 -9.04812028] La, [ 1...
# 4   [[ -3.75097439 -10.43915897  -9.12936741] La, ...
# 5   [[ 1.2611523  -0.06523272  1.24610485] La, [ 3...
# 6   [[  1.23313315 -10.42207692   1.29644454] La, ...
# 7   [[ -3.82589878 -10.3855898   -8.98870624] La, ...
# 8   [[  1.2942159  -10.4288387    1.21365453] La, ...
# 9   [[ 6.48514391 -5.08053982  1.24811179] Hf, [ 1...
# 10  [[-3.71694873  0.14977013  1.31482335] Hf, [-3...
# 11  [[ 1.22917854 -5.20724963 -8.98353563] La, [ 1...
# 12  [[ 1.2672519  -5.22235914  1.25502378] La, [ 6...
# 13  [[ 1.21605828 -0.02737895  1.2076708 ] La, [ 3...
# 14  [[-8.95252156  0.04077885 -8.97995403] La, [-6...
# 15  [[-8.89153425e+00  3.74592666e-03 -8.86548800e...
# 16  [[1.21658012 0.02782265 1.23455669] La, [8.988...
# 17  [[ 1.23229832 -5.19820603  1.20580575] La, [ 3...
# 18  [[-8.92244843  0.1001522  -8.88200293] La, [-1...
# 19  [[-3.72311375  0.16882582 -3.75624017] Hf, [-3...
# 20  [[-8.95451299  0.03167195 -3.7256452 ] La, [-8...
# 21  [[1.15270133 0.0919812  1.25918238] La, [1.153...
# 22  [[-8.91340581  0.08134477 -3.71735233] La, [-3...
# 23  [[1.1517937  0.06206555 1.26702473] La, [6.281...
# 24  [[-8.95758441  0.01069689 -3.85743455] La, [-6...
# 25  [[ 1.26846384 10.44853594  1.18120709] La, [8....
# 26  [[-8.92805587  0.08310084 -3.87297786] La, [-6...
# 27  [[1.22170882 0.09760965 1.26175677] La, [ 3.83...
# 28  [[1.21825655 0.12353266 1.27723848] La, [8.985...
# 29  [[-8.79886815  0.09836581 -3.7175504 ] La, [-1...
# 30  [[-8.70236652  5.38333349 -3.7335392 ] Hf, [-3...
# 31  [[ 1.25828194  0.07422469 -8.88975684] La, [ 6...
# 32  [[  1.20378755 -10.37289294   1.20684741] La, ...
# 33  [[  1.20239869 -10.37600321   1.23914808] La, ...
# 34  [[  1.25149742 -10.33170961   1.27050531] La, ...
# 35  [[ 1.28078313 -0.02758403  1.25354481] La, [ 8...
# 36  [[ -8.86354018 -10.34654788  -8.85273692] La, ...
# 37  [[  1.23344373 -10.32150592   1.20741965] La, ...
# 38  [[  1.23530591 -10.35593085   1.22515492] La, ...
# 39  [[ -8.81794157 -10.31732895  -8.85921025] La, ...
# 40  [[  1.26183591 -10.32420584   1.24100917] La, ...
# 41  [[ 1.36496635 -5.02569651  6.31079067] Hf, [ 6...
# 42  [[1.34257036 0.16844199 6.29240046] Hf, [6.379...
# 43  [[ 1.33187796  0.18672063 -3.78741591] Hf, [ 1...
# 44  [[6.37725921 0.16220284 1.21332885] Hf, [1.346...
# 45  [[-8.72437078  0.16153305 -3.7001223 ] Hf, [-3...
# 46  [[-3.69412307 -5.04460926  1.32668849] Hf, [-3...
# 47  [[  1.23552893 -10.39547903   1.17196386] La, ...
# 48  [[ 1.23069875  0.08053231 -8.93559988] La, [ 1...
# 49  [[-8.7264145   0.12573138 -8.74974161] La, [-8...
# 50  [[ 1.32500523 -5.06492154  1.653605  ] La, [ 1...
# 51  [[-8.79021619  0.12058117 -3.48165679] La, [-8...
# 52  [[-3.81465433 -0.01226589 -8.81884672] La, [ -...
# 53  [[  1.23137486 -10.41173086   1.2799407 ] La, ...
# 54  [[ 1.2378451   0.04250559 -8.9159875 ] La, [ 1...
# 55  [[ 1.25672819  0.03761848 -8.80072435] La, [ 1...
# 56  [[ -3.76427686 -10.35103945  -8.84571579] La, ...
# 57  [[-3.7807708   0.12141185  1.19768895] La, [-3...
# 58  [[ 1.22062754 -0.03220093  1.29852578] La, [  ...
# 59  [[ -3.69231602 -10.37043888  -8.70998847] La, ...
# 60  [[-8.7908754  -5.15751707 -8.9242446 ] La, [-8...
# 61  [[ 1.21538727  0.07122424 -8.89421079] La, [ 1...
# 62  [[-8.82685281 -5.20473387  1.44550981] La, [-8...
# 63  [[-8.85239719 -5.13684718 -8.88746185] La, [-8...
# 64  [[ 1.26972837 -5.1469884  -8.89764228] La, [ 1...
# 65  [[-8.81993574  0.03938369 -8.68538899] La, [-8...
# 66  [[ 1.26688429 -5.13573002  1.2577267 ] La, [ 1...
# 67  [[ 1.12316148 -5.16629265  1.30873369] La, [ 1...
# 68  [[-8.88213605  0.01851915 -3.71081466] La, [-8...
# 69  [[1.27306541 0.02249987 1.20555012] La, [1.365...
# 70  [[  1.12651653 -10.32629112  -3.78706426] La, ...
# 71  [[ -8.82360647 -10.37690307   1.48065793] La, ...
# 72  [[1.22168289 0.10278659 1.23968109] La, [1.371...
# 73  [[-8.79735704  0.08716133 -3.70212712] La, [-8...
# 74  [[-8.78882028e+00  6.95960870e-03 -3.79134636e...
# 75  [[ -8.78554658 -10.36165457   1.46881076] La, ...
# 76  [[  1.13729128 -10.37764477   1.2870564 ] La, ...
# 77  [[ -8.75033762 -10.374462    -8.84959354] La, ...
# 78  [[ -8.80343909 -10.31527668  -8.75162012] La, ...
# 79  [[ -8.76371304 -10.3495824   -8.6475231 ] La, ...
# 80  [[ -8.77657964 -10.29442935  -8.81160946] La, ...
# 81  [[  1.27995611 -10.29974321   1.16110606] La, ...
# 82  [[  1.29204998 -10.34433659   1.2622219 ] La, ...
# 83  [[  1.27453246 -10.31302383   1.30087753] La, ...
# 84  [[-8.75719333 -7.81877028 -6.17484473] La, [-1...
# 85  [[ 1.18939786 10.3913493  -9.10396763] La, [ 1...
# 86  [[-8.92827658 -0.03723875 -8.9405505 ] La, [-6...
# 87  [[-8.89005857 -7.87452594 -6.37011408] La, [-6...
# 88  [[-8.74097591 -0.04181491 -8.8299728 ] La, [-1...
# 89  [[-1.18407398 -7.78189794 -8.86378305] La, [-1...
# 90  [[  1.28545552 -10.34749983   1.1663954 ] La, ...
# 91  [[ 1.33847613 -7.78244072  3.80673071] La, [ 8...
# 92  [[ -8.75347199 -10.35885911  -8.93497506] La, ...
# 93  [[ 1.21010225 -0.04243974  1.18664188] La, [ 3...
# 94  [[-8.91737071 -7.87002883 -6.31688805] La, [-6...
# 95  [[-6.32739935 -7.76218739 -8.93890052] La, [-6...
# 96  [[  5.49959237  -7.55914851 -10.43734567] La, ...
# 97  [[-4.39644506  2.97034064  0.3334635 ] La, [-8...
# 98  [[5.99738519 2.70065929 0.2573197 ] La, [1.407...
#
#                              name
# 0     Hf14La2O32_sc122_No29_1.cif
# 1     Hf14La2O32_sc122_No29_2.cif
# 2     Hf14La2O32_sc122_No29_3.cif
# 3     Hf14La2O32_sc122_No29_4.cif
# 71    Hf15LaO31_sc221_No29_20.cif
# 72    Hf15LaO31_sc221_No29_21.cif
# 73    Hf15LaO31_sc221_No29_22.cif
# 74    Hf15LaO31_sc221_No29_23.cif
# 75    Hf15LaO31_sc221_No29_24.cif
# 76     Hf31LaO63_sc222_No29_1.cif
# 77     Hf31LaO63_sc222_No29_2.cif
# 78     Hf31LaO63_sc222_No29_3.cif
# 79     Hf31LaO63_sc222_No29_4.cif
# 80     Hf31LaO63_sc222_No29_5.cif
# 81     Hf31LaO63_sc222_No29_6.cif
# 82     Hf31LaO63_sc222_No29_7.cif
# 83     Hf31LaO63_sc222_No29_8.cif
# 84    Hf30La2O63_sc222_No29_1.cif
# 85   Hf30La2O63_sc222_No29_10.cif
# 86   Hf30La2O63_sc222_No29_11.cif
# 87   Hf30La2O63_sc222_No29_12.cif
# 88    Hf30La2O63_sc222_No29_2.cif
# 89    Hf30La2O63_sc222_No29_3.cif
# 90    Hf30La2O63_sc222_No29_4.cif
# 91    Hf30La2O63_sc222_No29_5.cif
# 92    Hf30La2O63_sc222_No29_6.cif
# 93    Hf30La2O63_sc222_No29_7.cif
# 94    Hf30La2O63_sc222_No29_8.cif
# 95    Hf30La2O63_sc222_No29_9.cif
# 96  La_HfO2_inter_3.125_222_o.cif
# 97   La_HfO2_inter_6.25_212_o.cif
# 98   La_HfO2_inter_6.25_221_o.cif

# %%
df['labels'] = df['labels'].str.extract(r'([a-zA-Z]+)')

# %%
df.lables_0_3_ = df.lables_0_3_.str.replace('p','p-o')

# %%
df  = df.drop(columns=['labels'])

# %%
df.to_pickle(r'C:\Python\Projects\crystal-phase-prediction\data\pkl_files\structures\structure_df_hfo2_La_del_defects_o.pkl')

# %%
labels_true = df['labels']
labels_true
# Out:
# 0       2La
# 1       2La
# 2       2La
# 3       2La
# 4       2La
# 5       2La
# 6       2La
# 7       2La
# 8       2La
# 9       2La
# 10      2La
# 11      2La
# 12      2La
# 13      2La
# 14      2La
# 15      2La
# 16      2La
# 17      2La
# 18      2La
# 19      2La
# 20      2La
# 21      2La
# 22      2La
# 23      2La
# 24      2La
# 25      2La
# 26      2La
# 27      2La
# 28      2La
# 29      2La
# 30      2La
# 31      2La
# 32      2La
# 33      2La
# 34      2La
# 35      2La
# 36      2La
# 37      2La
# 38      2La
# 39      2La
# 40      2La
# 41      2La
# 42      2La
# 43      2La
# 44      2La
# 45      2La
# 46      2La
# 47      2La
# 48      2La
# 49      2La
# 50      2La
# 51      2La
# 52      LaV
# 53      LaV
# 54      LaV
# 55      LaV
# 56      LaV
# 57      LaV
# 58      LaV
# 59      LaV
# 60      LaV
# 61      LaV
# 62      LaV
# 63      LaV
# 64      LaV
# 65      LaV
# 66      LaV
# 67      LaV
# 68      LaV
# 69      LaV
# 70      LaV
# 71      LaV
# 72      LaV
# 73      LaV
# 74      LaV
# 75      LaV
# 76      LaV
# 77      LaV
# 78      LaV
# 79      LaV
# 80      LaV
# 81      LaV
# 82      LaV
# 83      LaV
# 84     La2V
# 85     La2V
# 86     La2V
# 87     La2V
# 88     La2V
# 89     La2V
# 90     La2V
# 91     La2V
# 92     La2V
# 93     La2V
# 94     La2V
# 95     La2V
# 96    inter
# 97    inter
# 98    inter
# Name: labels, dtype: object

# %%
labels_true.to_pickle(r'C:\Python\Projects\crystal-phase-prediction\data\data_labels\La_defects_labels_o.pkl')
